# %% [markdown]
# Le vecteur est définit dans types.py
# On utilise matplotlib pour le dessiner et numpy pour faire des calculs précis

# %%
# %matplotlib notebook
from scene import scene
from rotation import vector
import numpy as np
import ipywidgets as widgets

# %% [markdown]
# Commençons par tracer le vecteur V = \[1 2 3\] dans l'espace:

# %%
# On crée une scène pour cette démonstration
s1 = scene()

# On crée le vecteur V qui part de l'origine à [1, 2, 3]
V = vector([1, 2, 3])

# On dessine le vecteur
s1.Q = s1.quiver(V)
s1.fig.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Si on pose un vecteur unitaire représentant l'axe des X

# %%
# Dessin du vecteur unitaire x à l'origine de V
s1.quiver(s1.xunit(V), "red")

# %% [markdown]
# Faisons-le tourner par rapport à l'axe des x

# %%
# Production du slider qui définit l'angle du vecteur par rapport au vecteur unitaire en x
widgets.interact(s1.draw_2D_rotation, dir = widgets.fixed(s1.xunit(V)), \
                 v = widgets.fixed(V), \
                 angle = s1.make_angle_slider())
# Out:
# Widget Javascript not detected.  It may not be installed or enabled properly.
# <function ipywidgets.widgets.interaction._InteractFactory.__call__.<locals>.<lambda>>

# %% [markdown]
# On peut rajouter un axe en y pour le faire tourner en 3D

# %%
# On crée une deuxième scène pour la démonstration en 3D
s2 = scene()

# On trace les vecteurs unitaires en x et en y
s2.quiver(s2.xunit(V), "red")
s2.quiver(s2.yunit(V), "blue")

# On trace deux sliders pour définir l'angle autour des vecteurs unitaires en x et y
widgets.interact(s2.draw_3D_rotation,
                 v = widgets.fixed(V),
                 angleX = s2.make_angle_slider(),
                 angleY = s2.make_angle_slider())
# Out:
# <img src="data:image/png;base64,..." width="640">
# Widget Javascript not detected.  It may not be installed or enabled properly.
# <function ipywidgets.widgets.interaction._InteractFactory.__call__.<locals>.<lambda>>

# %% [markdown]
# # À faire
#
# - Tracer un plan par vecteur unitaire
# - Tracer un cercle de rayon Vi dans chaque plan
#
# ## Scène 3
#
# - Produire un cube de hauteur 4 autour de l'origine
#     - x + y = 2
#     - x + y = -2
#     - x + z = 2
#     - x + z =
# - Le faire tourner en 3D de la même façon
